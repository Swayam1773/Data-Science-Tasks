# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#First point

# %%
def averagemale(group_name):
    name = df['race/ethnicity'] == group_name
    name1 = df[name]
    t = name1['gender'] == 'male'
    return name1[t].mean()

# %%
def averagefemale(group_name):
    name = df['race/ethnicity'] == group_name
    name1 = df[name]
    t = name1['gender'] == 'female'
    return name1[t].mean()

# %%
#new

# %%
averagemale('group A')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/3536954316.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       63.735849
# reading score    61.735849
# writing score    59.150943
# dtype: float64

# %%
averagefemale('group A')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/2281150369.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       58.527778
# reading score    69.000000
# writing score    67.861111
# dtype: float64

# %%
averagemale('group B')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/3536954316.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       65.930233
# reading score    62.848837
# writing score    60.220930
# dtype: float64

# %%
averagefemale('group B')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/2281150369.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       61.403846
# reading score    71.076923
# writing score    70.048077
# dtype: float64

# %%
averagemale('group C')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/3536954316.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       67.611511
# reading score    65.424460
# writing score    62.712230
# dtype: float64

# %%
averagefemale('group C')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/2281150369.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       62.033333
# reading score    71.944444
# writing score    71.777778
# dtype: float64

# %%
averagemale('group D')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/3536954316.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       69.413534
# reading score    66.135338
# writing score    65.413534
# dtype: float64

# %%
averagefemale('group D')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/2281150369.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       65.248062
# reading score    74.046512
# writing score    75.023256
# dtype: float64

# %%
averagemale('group E')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/3536954316.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       76.746479
# reading score    70.295775
# writing score    67.394366
# dtype: float64

# %%
averagefemale('group E')
# Out:
# C:\Users\s-sin\AppData\Local\Temp/ipykernel_17780/2281150369.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return name1[t].mean()
# math score       70.811594
# reading score    75.840580
# writing score    75.536232
# dtype: float64

# %%
# End of first point

# %%
# Second Point

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
x = df['parental level of education'] == 'bachelor\'s degree'

# %%
a = df[x]

# %%
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 916    male        group E           bachelor's degree      standard
# 933    male        group C           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
t1 = a['gender'] == 'male'

# %%
s = a[t1]

# %%
s
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 24    male        group D           bachelor's degree  free/reduced
# 60    male        group E           bachelor's degree  free/reduced
# 77    male        group A           bachelor's degree      standard
# 101   male        group D           bachelor's degree      standard
# 134   male        group D           bachelor's degree  free/reduced
# 135   male        group C           bachelor's degree      standard
# 151   male        group A           bachelor's degree      standard
# 153   male        group D           bachelor's degree      standard
# 206   male        group E           bachelor's degree      standard
# 234   male        group C           bachelor's degree      standard
# 236   male        group D           bachelor's degree  free/reduced
# 270   male        group C           bachelor's degree      standard
# 275   male        group C           bachelor's degree      standard
# ...

# %%
d = s[(s['math score'] > 80) & (s['reading score'] > 85)]

# %%
d
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 551   male        group B           bachelor's degree  free/reduced
# 562   male        group C           bachelor's degree      standard
# 571   male        group A           bachelor's degree      standard
# 612   male        group C           bachelor's degree      standard
# 916   male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 551               completed          87             90             88
# 562               completed          96             90             92
# 571                    none          91             96             92
# 612               completed          94             90             91
# 916               completed         100            100            100

# %%
len(d.axes[0])
# Out:
# 5

# %%
len(s.axes[0])
# Out:
# 55

# %%
print(5/55*100)
# Out:
# 9.090909090909092

# %%
#End of second point

# %%
#Third Point

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
s1 = df[((df['parental level of education'] == 'high school') | (df['parental level of education'] == 'bachelor\'s degree')) & (df['gender'] == 'male') & (df['race/ethnicity'] == 'group E')]

# %%
s1
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 60    male        group E           bachelor's degree  free/reduced
# 137   male        group E                 high school      standard
# 186   male        group E                 high school      standard
# 197   male        group E                 high school  free/reduced
# 206   male        group E           bachelor's degree      standard
# 207   male        group E                 high school      standard
# 214   male        group E                 high school      standard
# 415   male        group E                 high school      standard
# 419   male        group E                 high school  free/reduced
# 476   male        group E           bachelor's degree      standard
# 538   male        group E           bachelor's degree      standard
# 592   male        group E           bachelor's degree      standard
# 757   male        group E           bachelor's degree  free/reduced
# ...

# %%
len(s1.axes[0])
# Out:
# 18

# %%
# End of third point

# %%
#fourth Point

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
def maxmarks(groupname):
    k = df['race/ethnicity'] == groupname
    s = df[k]
    m = s['math score']
    r = s['reading score']
    w = s['writing score']
    mm = m.max()
    mr = r.max()
    mw = w.max()
    a = [mr,mw,mm]
    return [mr,mm,mw]

# %%
maxmarks('group A')
# Out:
# [100, 100, 97]

# %%
maxmarks('group B')
# Out:
# [97, 97, 96]

# %%
maxmarks('group C')
# Out:
# [100, 98, 100]

# %%
maxmarks('group D')
# Out:
# [100, 100, 100]

# %%
maxmarks('group E')
# Out:
# [100, 100, 100]

# %%
import matplotlib.pyplot as plt

# %%
dict = {'group A':[100,100,97] , 'group B':[97, 97, 96],'group C':[100, 98, 100],'group D':[100, 100, 100],'group E':[100, 100, 100]}

# %%
mi = ['math','reading','writing']

# %%
gh = pd.DataFrame(dict,index = mi)

# %%
gh
# Out:
#          group A  group B  group C  group D  group E
# math         100       97      100      100      100
# reading      100       97       98      100      100
# writing       97       96      100      100      100

# %%
gh.plot()
# Out:
# <AxesSubplot:>

# %%
#Fourth Point end

# %%
#Fifth point

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
fp = df[(df['gender'] == 'female') & (df['test preparation course'] == 'completed')]

# %%
fnp = df[(df['gender'] == 'female') & (df['test preparation course'] == 'none')]

# %%
mp = df[(df['gender'] == 'male') & (df['test preparation course'] == 'completed')]

# %%
mnp = df[(df['gender'] == 'male') & (df['test preparation course'] == 'none')]

# %%
dict = {'female prepared': len(fp.axes[0]) , 'Male prepared': len(mp.axes[0]) , 'Female not prepared':len(fnp.axes[0]) , 'male not prepared': len(mnp.axes[0])}

# %%
ji = ['female prepared',]

# %%
ty = pd.DataFrame(data = dict , index = ji)

# %%
f = ty.transpose()

# %%
f.plot()
# Out:
# <AxesSubplot:>

# %%
#End of fifth point

# %%
#Sixth point
